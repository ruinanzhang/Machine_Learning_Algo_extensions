# %% [markdown]
# ## NYU Machine Learning final project Algo I - SVM - Scikit-learn Implementation

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import model_selection, svm, preprocessing
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import style

# %% [markdown]
# ### Import Data -- Iris (Dataset used in HW3)

# %%
import seaborn as sns
# Load Iris data from Seaborn 
# Imported as Pandas DataFrame
iris = sns.load_dataset('iris')
# Check the first five data 
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Plot pairplot to see the distribution of the data
sns.pairplot(iris,hue='species',palette="husl",markers=["o", "s", "D"])

# %% [markdown]
# ##### Observation of the data:
# We can see while **Setosa** is more likely to be **linearly separable** in 2-d space from the other two species, **Versicolor and Virginica** seem to have some overlaps in all features space: sepal_length sepal_width petal_length and petal_width. So from the observation of the data, we can indicate that soft margin SVM will have a better performance than hard margin SVM

# %%
from sklearn.model_selection import train_test_split
X = iris.drop('species',axis=1)
y = iris['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 42)
print("Our training and test data shapes:")
print("x_train dim and type: ", X_train.shape)
print("y_train dim and type: ", y_train.shape)
print("x_test dim and type: ", X_test.shape)
print("y_test dim and type: ", y_test.shape)
# Out:
# Our training and test data shapes:
# x_train dim and type:  (100, 4)
# y_train dim and type:  (100,)
# x_test dim and type:  (50, 4)
# y_test dim and type:  (50,)

# %% [markdown]
# ## Section 1 : Using scikit function that emulates the SVM done in class and running it on Iris Dataset

# %% [markdown]
# In hw9, we implemented the hard margin SVM finds the seperating decision bounary with the largest margin -- which means no data points are allowed in the margin areas.
#
# We also tried to use quadratic problem solver to solve both primal and dual problem for hard margin SVM.
#
# In homework, we only ran the hard margin SVM on binary classification for data points. Let's exlpore how it would work for images.

# %% [markdown]
# ### Build hard margin SVM model using Sklearn

# %%
from sklearn import datasets, svm, metrics
import datetime as dt

# %% [markdown]
# **Explanination about Sklearn SVM's margin implementation**
#
#
# >The plots below illustrate the effect the parameter C has on the separation line. A large value of C basically tells our model that we do not have that much faith in our data’s distribution, and will only consider points close to line of separation.
#
# >A small value of C includes more/all the observations, allowing the margins to be calculated using all the data in the area.
#
# >Reference: https://scikit-learn.org/stable/auto_examples/svm/plot_svm_margin.html
#
# **In summary:**
#
# **C is a regularization parameter for SVMs, it controls how much you want to punish your model for each misclassified point for a given curve. The lower the C parameters, the softer the margin.**

# %% [markdown]
# <img src="sklearn_svm_margin.png">

# %%
# Thus, for hard margin, we increase the regularization parameter of SVM to C = 1000
param_C = 1000
# Build model
classifier_hard_margin = svm.SVC(C=param_C,kernel ="linear")

start_time = dt.datetime.now()
print('Start learning at {}'.format(str(start_time)))
# Train model
classifier_hard_margin.fit(X_train, y_train)
end_time = dt.datetime.now() 
print('Stop learning {}'.format(str(end_time)))
elapsed_time= end_time - start_time
print('Elapsed learning {}'.format(str(elapsed_time)))
# Out:
# Start learning at 2020-05-05 17:46:09.934549
# Stop learning 2020-05-05 17:46:09.936934
# Elapsed learning 0:00:00.002385

# %%
# Get confusion matrix and accuracy: 
expected_hard_margin = y_test
predicted_hard_margin = classifier_hard_margin.predict(X_test)
print("Classification report for classifier %s:\n%s\n"
      % (classifier_hard_margin, metrics.classification_report(expected_hard_margin, predicted_hard_margin)))    
cm = metrics.confusion_matrix(expected_hard_margin, predicted_hard_margin)
print("Confusion matrix:\n%s" % cm)
print("Accuracy={}".format(metrics.accuracy_score(expected_hard_margin, predicted_hard_margin)))
# Out:
# Classification report for classifier SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False):
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
#
# Confusion matrix:
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  1 15]]
# Accuracy=0.98

# %% [markdown]
# **Cross validation**
#
# Since we have a small dataset, it's fair to also use cross validation to check the accuracy

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear', C=1000, random_state=40)
scores_hard = cross_val_score(clf, X, y, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_hard.mean(), scores_hard.std() * 2))
# Out:
# Accuracy: 0.97 (+/- 0.08)

# %% [markdown]
# **Accuracy sumary for hard margin SVM :**
#
# **Accuracy classification score on test set: 0.98**
#
# **Cross Validation accuracy score: 0.97 (+/- 0.08)**

# %% [markdown]
# ## Section 2: Using scikit function that includes the suggested extension and running it on Iris Dataset

# %% [markdown]
# ### Implement soft margin SVM
# As we discussed in the hard margin, in Sklearn, the way to implement soft margin is to tune param_C to a smaller number, for thia data set, we **chose C=1.5** for soft margin

# %%
# For soft margin -> decrese the regularization parameter of SVM to C = 1.5
param_C =1.5
classifier_soft = svm.SVC(C=param_C,kernel='linear')

#We learn the digits on train part
start_time = dt.datetime.now()
print('Start learning at {}'.format(str(start_time)))
classifier_soft.fit(X_train, y_train)
end_time = dt.datetime.now() 
print('Stop learning {}'.format(str(end_time)))
elapsed_time= end_time - start_time
print('Elapsed learning {}'.format(str(elapsed_time)))
# Out:
# Start learning at 2020-05-05 17:47:33.454530
# Stop learning 2020-05-05 17:47:33.457535
# Elapsed learning 0:00:00.003005

# %%
# Get confusion matrix and accuracy: 
expected = y_test
predicted_soft = classifier_soft.predict(X_test)
print("Classification report for classifier %s:\n%s\n"
      % (classifier_soft, metrics.classification_report(expected, predicted_soft)))
      
cm = metrics.confusion_matrix(expected, predicted_soft)
print("Confusion matrix:\n%s" % cm)

print("Accuracy={}".format(metrics.accuracy_score(expected, predicted_soft)))
# Out:
# Classification report for classifier SVC(C=1.5, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False):
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        15
#    virginica       1.00      1.00      1.00        16
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50
#
#
# Confusion matrix:
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 16]]
# Accuracy=1.0

# %% [markdown]
# **Cross Validation for Soft margin**

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear', C=1.5, random_state=40)
scores_soft = cross_val_score(clf, X, y, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_soft.mean(), scores_soft.std() * 2))
# Out:
# Accuracy: 0.98 (+/- 0.03)

# %% [markdown]
# **Accuracy sumary for soft margin SVM :**
#
# **Accuracy classification score on test set : 1.00**
#
# **Cross Validation accuracy score: 0.98 (+/- 0.03)**

# %%
# Plot scores on Test set
from matplotlib import pyplot as plt
s_t = [0.98,0.98]
h_t = [1,1]
plt.plot(s_t,label='hard margin -test val')
plt.plot(h_t,label='soft margin -test val')
plt.legend()
axes = plt.axes()
axes.set_ylim([0, 1.1])
plt.ylabel("Accuracy")
plt.title("Improve in test validation")
# Out:
# /Users/kathola/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Text(0.5, 1.0, 'Improve in test validation')

# %%
# Plot scores from corss validation 
from matplotlib import pyplot as plt
plt.plot(scores_hard,label='hard margin -cv')
plt.plot(scores_soft,label='soft margin -cv')
plt.legend()
plt.xlabel("Group/cv")
plt.ylabel("Accuracy")
plt.title("Improve in cross validation")
# Out:
# Text(0.5, 1.0, 'Improve in cross validation')

# %% [markdown]
# ### Section 1&2 summary: ##
# **Using Sklearn to implement hard margin and soft margin of SVM, We can see that Soft margin improved accuracy for 2% for our test set and improved for about 1% in average using cross validation.**

# %% [markdown]
# ## Section 3 : Using scikit function that emulates the SVM done in class and running it on UCI ML Breast Cancer Wisconsin (Diagnostic) dataset

# %%
from sklearn.datasets import load_breast_cancer # The breast cancer data set is in scikit learn data set
import pandas as pd
data_breast_cancer = load_breast_cancer()
X2 = data_breast_cancer.data
y2 = data_breast_cancer.target

# %%
#Then we take a closer look at our Dataset:
#To better plot the data, we transform our dataset into pandas data frame: 
cancer_db = pd.DataFrame(np.c_[data_breast_cancer['data'], data_breast_cancer['target']], columns=np.append(data_breast_cancer['feature_names'], ['target']))
cancer_db.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890     0.0
# 1          0.2750                  0.08902     0.0
# 2          0.3613                  0.08758     0.0
# 3          0.6638                  0.17300     0.0
# 4          0.2364                  0.07678     0.0
#
# [5 rows x 31 columns]

# %%
# Plot the data: 
sns.pairplot(data,palette="husl",markers=["o", "s"], hue='target', vars=['mean radius', 'mean texture', 'mean area', 'mean perimeter', 'mean smoothness'])
plt.show()

# %%
#Split the data into training and test set.  80% training and %20 test
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2)

# %% [markdown]
# ### Implement hard margin SVM, here we will use the exatcly same param_C as in Section 1

# %%
param_C = 1000
# Build model
classifier_hard_margin_2 = svm.SVC(C=param_C,gamma=0.001,kernel ="rbf")

start_time = dt.datetime.now()
print('Start learning at {}'.format(str(start_time)))
# Train model
classifier_hard_margin_2.fit(X2_train, y2_train)
end_time = dt.datetime.now() 
print('Stop learning {}'.format(str(end_time)))
elapsed_time= end_time - start_time
print('Elapsed learning {}'.format(str(elapsed_time)))
# Out:
# Start learning at 2020-05-06 01:14:09.786793
# Stop learning 2020-05-06 01:14:09.806508
# Elapsed learning 0:00:00.019715

# %%
# Get confusion matrix and accuracy: 
expected2 = y2_test
predicted_hard_2 = classifier_hard_margin_2.predict(X2_test)
print("Classification report for classifier %s:\n%s\n"
      % (classifier_hard_margin_2, metrics.classification_report(expected2, predicted_hard_2)))
      
cm = metrics.confusion_matrix(expected2, predicted_hard_2)
print("Confusion matrix:\n%s" % cm)

print("Accuracy={}".format(metrics.accuracy_score(expected2, predicted_hard_2)))
# Out:
# Classification report for classifier SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False):
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        44
#            1       0.97      0.90      0.93        70
#
#     accuracy                           0.92       114
#    macro avg       0.91      0.93      0.92       114
# weighted avg       0.93      0.92      0.92       114
#
#
# Confusion matrix:
# [[42  2]
#  [ 7 63]]
# Accuracy=0.9210526315789473

# %% [markdown]
# **Cross Val on this data set**

# %%
clf = svm.SVC(kernel='rbf', C=1000, random_state=0,gamma=0.001)
scores_hard_2 = cross_val_score(clf, X2, y2, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_hard_2.mean(), scores_hard_2.std() * 2))
# Out:
# Accuracy: 0.91 (+/- 0.04)

# %% [markdown]
# **Accuracy sumary for soft margin SVM on Breast Cancer:**
#
# **Accuracy classification score on test set : 0.92**
#
# **Cross Validation accuracy score: 0.91 (+/- 0.04)**

# %% [markdown]
# ## Section 4: Using scikit function that includes the suggested extension and running it on UCI ML Breast Cancer Wisconsin (Diagnostic) dataset

# %% [markdown]
# ### Implementing soft margin

# %%
param_C =1
# Build model
classifier_soft_margin_2 = svm.SVC(C=param_C,kernel ='rbf',gamma=0.001)

start_time = dt.datetime.now()
print('Start learning at {}'.format(str(start_time)))
# Train model
classifier_soft_margin_2.fit(X2_train, y2_train)
end_time = dt.datetime.now() 
print('Stop learning {}'.format(str(end_time)))
elapsed_time= end_time - start_time
print('Elapsed learning {}'.format(str(elapsed_time)))
# Out:
# Start learning at 2020-05-06 01:14:25.563980
# Stop learning 2020-05-06 01:14:25.590319
# Elapsed learning 0:00:00.026339

# %%
expected2 = y2_test
predicted_soft_2 = classifier_soft_margin_2.predict(X2_test)
print("Classification report for classifier %s:\n%s\n"
      % (classifier_soft_margin_2, metrics.classification_report(expected2, predicted_soft_2)))
      
cm = metrics.confusion_matrix(expected2, predicted_soft_2)
print("Confusion matrix:\n%s" % cm)

print("Accuracy={}".format(metrics.accuracy_score(expected2, predicted_soft_2)))
# Out:
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False):
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.93        44
#            1       0.98      0.93      0.96        70
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.95       114
# weighted avg       0.95      0.95      0.95       114
#
#
# Confusion matrix:
# [[43  1]
#  [ 5 65]]
# Accuracy=0.9473684210526315

# %%
clf = svm.SVC(C=1.5,kernel ='rbf',gamma=0.001)
scores_soft_2 = cross_val_score(clf, X2, y2, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_soft_2.mean(), scores_soft_2.std() * 2))
# Out:
# Accuracy: 0.92 (+/- 0.03)

# %% [markdown]
# **Accuracy sumary for soft margin SVM on Breast Cancer:**
#
# **Accuracy classification score on test set : 0.95**
#
# **Cross Validation accuracy score: 0.92 (+/- 0.03)**

# %%
# Plot scores on Test set
from matplotlib import pyplot as plt
s_t = [0.91,0.91]
h_t = [0.95,0.95]

plt.plot(s_t,label='hard margin -test val')
plt.plot(h_t,label='soft margin -test val')
axes = plt.axes()
axes.set_ylim([0, 1])
plt.plot(b_t)
plt.legend()
plt.ylabel("Accuracy")
plt.title("Improvement on test val (Breast Cancer db)")
# Out:
# /Users/kathola/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Text(0.5, 1.0, 'Improvement on test val (Breast Cancer db)')

# %%
# Plot scores from corss validation 
from matplotlib import pyplot as plt
plt.plot(scores_hard_2,label='hard margin -cv')
plt.plot(scores_soft_2,label='soft margin -cv')
plt.legend()
plt.xlabel("Group/cv")
plt.ylabel("Accuracy")
plt.title("Improve in cross validation on Breast Cancer db")
# Out:
# Text(0.5, 1.0, 'Improve in cross validation on Breast Cancer db')

# %% [markdown]
# ### Section 3&4 summary: ##
# **Using Sklearn to implement hard margin and soft margin of SVM on Breast Cancer dataset, We can see that Soft margin improved accuracy for 4% for our test set and improved for about 1% in average using cross validation.**

# %% [markdown]
# **References:**
#
# >[1]**Scikit-learn Library** https://scikit-learn.org/
